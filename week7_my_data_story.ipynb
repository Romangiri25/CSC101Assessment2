# %%
# Week 8 - My Data Story
# Reading my personal text file

filename = "my_data.txt"

contents = []

with open(filename, "r") as file:
    contents = file.readlines()

print("=== MY DATA STORY ===")
print("=== FILE CONTENTS ===")

for line in contents:
    print(line.strip())
# Out:
# === MY DATA STORY ===
# === FILE CONTENTS ===
# Programming is the process of creating instructions that a computer follows to perform tasks. It involves writing code using programming languages like Python or Java. Programmers use logic, problem-solving, and creativity to build software, websites, and apps that solve real-world problems and make tasks faster and more efficient.

# %%
# Number of lines
num_lines = len(contents)

# Number of words
num_words = 0
for line in contents:
    num_words += len(line.split())

# Total characters
num_chars = 0
for line in contents:
    num_chars += len(line)

# First and last line
first_line = contents[0].strip()
last_line = contents[-1].strip()

print("\n=== FILE STATISTICS ===")
print("Number of lines:", num_lines)
print("Number of words:", num_words)
print("Total characters:", num_chars)
print("First line:", first_line)
print("Last line:", last_line)
# Out:
# === FILE STATISTICS ===
# Number of lines: 1
# Number of words: 48
# Total characters: 333
# First line: Programming is the process of creating instructions that a computer follows to perform tasks. It involves writing code using programming languages like Python or Java. Programmers use logic, problem-solving, and creativity to build software, websites, and apps that solve real-world problems and make tasks faster and more efficient.
# Last line: Programming is the process of creating instructions that a computer follows to perform tasks. It involves writing code using programming languages like Python or Java. Programmers use logic, problem-solving, and creativity to build software, websites, and apps that solve real-world problems and make tasks faster and more efficient.

# %%
## AI Collaboration Log

**My AI Prompt:**  
Write beginner Python code to read a text file and count number of lines, words, characters and print file contents.

what the AI Assisted Me With:  
AI taught me to open and read a file in Python and how to compute the simplest statistics with the help of loops.

**What I Learned:**  
I understood the principle of working with files in Python and was able to find valuable information in text files.

# %%
## My Reflection

What struck me about working with files:  
I was astonished by the fact that with the help of a few lines of code, Python can read and analyze a complete file.

How this relates to business:  
File processing in businesses is a way of automatically analyzing data such as sales records, customer data and reports.

The next thing I would like to know:  
I would like to know how to work with Excel files and real-life data in Python.
